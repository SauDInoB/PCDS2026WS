# %%
#Let's import libs already installed that will be used within the script
import pandas as pd
import matplotlib.pyplot as plt
import os
import json

# %%
#Confirm whether they have been installed
print ("importing done")
# Out:
# importing done

# %%
#You can change the name of the database
filename="asthma_best_db.sav"
# We may need to create a report in the end. Let's create an empty list for that
to_report=[]

# %%
#The following block of code will allow for the creation of an dynamic path regardless of the computer the script is running on
current_dir=os.getcwd()
d2s1_folder=os.path.dirname(current_dir)
bd_path="data/raw"

# %%
#Now we create a personalized absolute path for the database
db_full_path=os.path.join(d2s1_folder, bd_path,filename)
print (db_full_path)
# Out:
# /Users/danielmdias/docs/5.homelab/code/PCDS2026WS/d2s1/data/raw/asthma_best_db.sav

# %%
#We create a new object called my_df. Now we create a personalized absolute path for the database
my_df =pd.read_spss(db_full_path)

# %%
# Now we check the shape and columnnames
print("The shape of the dataframe is :", my_df.shape)
columns=my_df.columns.tolist()    
print ("There are", len (columns), "columns in the df")
print("\nColumns are :", columns)
# Out:
# The shape of the dataframe is : (888, 31)
# There are 31 columns in the df
#
# Columns are : ['SEQN', 'RIAGENDR', 'RIDAGEEX', 'raca_etnia', 'DMDHHSIZ', 'BMXWT', 'BMXHT', 'BMXBMI', 'LBXHGB', 'LBXHCT', 'ENQ100', 'ENXMEAN', 'MCQ010', 'MCQ025', 'RDQ031', 'RDQ050', 'RDQ070', 'RDQ090', 'RDQ100', 'RDQ134', 'RDQ140', 'AGQ030', 'SMQ020', 'SMD030', 'SMQ040', 'SPXNFVC', 'SPXNFEV1', 'SPXNPEF', 'SPXBFVC', 'SPXBFEV1', 'SPXBPEF']

# %%
# We check the head and tail of the df
# print(my_df.head())
print (my_df.tail())
# Out:
#         SEQN  RIAGENDR  RIDAGEEX  raca_etnia  DMDHHSIZ  BMXWT  BMXHT  BMXBMI  \
# 883  57079.0  Feminino     880.0  Hispânicos       1.0   59.9  162.8   22.60
# 884  48715.0  Feminino     882.0  Hispânicos       6.0   65.5  153.9   27.65
# 885  53444.0  Feminino     908.0  Hispânicos       2.0   46.6  148.7   21.07
# 886  59091.0  Feminino     914.0  Hispânicos       1.0   69.0  153.0   29.48
# 887  45293.0  Feminino     923.0  Hispânicos       4.0   45.5  154.3   19.11
#
#      LBXHGB  LBXHCT  ...  AGQ030  SMQ020 SMD030  SMQ040  SPXNFVC  SPXNFEV1  \
# 883    13.7    38.7  ...     2.0     1.0   20.0     3.0   2152.0    1709.0
# 884    13.4    37.9  ...     2.0     1.0   11.0     3.0   2262.0    1836.0
# 885     8.7    26.0  ...     1.0     1.0   30.0     3.0      NaN       NaN
# 886    15.2    44.1  ...     2.0     2.0    NaN     NaN   2258.0    1362.0
# 887    13.1    39.3  ...     2.0     2.0    NaN     NaN   1786.0     984.0
#
#      SPXNPEF  SPXBFVC  SPXBFEV1  SPXBPEF
# 883   4475.0      NaN       NaN      NaN
# 884   5128.0      NaN       NaN      NaN
# 885      NaN      NaN       NaN      NaN
# 886   2575.0   2619.0    1528.0   3705.0
# 887   1093.0      NaN       NaN      NaN
#
# [5 rows x 31 columns]

# %%
# We check the datatype of each column
print("\nData types:")
print(my_df.dtypes)
# Out:
# Data types:
# SEQN           float64
# RIAGENDR      category
# RIDAGEEX       float64
# raca_etnia    category
# DMDHHSIZ       float64
# BMXWT          float64
# BMXHT          float64
# BMXBMI         float64
# LBXHGB         float64
# LBXHCT         float64
# ENQ100         float64
# ENXMEAN        float64
# MCQ010        category
# MCQ025         float64
# RDQ031         float64
# RDQ050         float64
# RDQ070         float64
# RDQ090         float64
# RDQ100         float64
# RDQ134         float64
# RDQ140         float64
# AGQ030         float64
# SMQ020         float64
# SMD030         float64
# SMQ040         float64
# SPXNFVC        float64
# SPXNFEV1       float64
# SPXNPEF        float64
# SPXBFVC        float64
# SPXBFEV1       float64
# SPXBPEF        float64
# dtype: object

# %%
def get_missings(df,column_name):
    num_missing = df[f"{column_name}"].isna().sum()
    result=num_missing
    return result

# %%
# get missings for every column available in the df
print(get_missings(my_df,"SMQ040"))

for column in columns:
    column_missings=get_missings(my_df, column)
    print("Missings in", column,":", column_missings)
# Out:
# 636
# Missings in SEQN : 0
# Missings in RIAGENDR : 0
# Missings in RIDAGEEX : 0
# Missings in raca_etnia : 0
# Missings in DMDHHSIZ : 0
# Missings in BMXWT : 10
# Missings in BMXHT : 86
# Missings in BMXBMI : 87
# Missings in LBXHGB : 146
# Missings in LBXHCT : 146
# Missings in ENQ100 : 270
# Missings in ENXMEAN : 278
# Missings in MCQ010 : 47
# Missings in MCQ025 : 766
# Missings in RDQ031 : 567
# Missings in RDQ050 : 567
# Missings in RDQ070 : 47
# Missings in RDQ090 : 773
# Missings in RDQ100 : 773
# Missings in RDQ134 : 773
# Missings in RDQ140 : 47
# Missings in AGQ030 : 47
# Missings in SMQ020 : 376
# Missings in SMD030 : 636
# Missings in SMQ040 : 636
# Missings in SPXNFVC : 276
# Missings in SPXNFEV1 : 276
# Missings in SPXNPEF : 276
# Missings in SPXBFVC : 835
# Missings in SPXBFEV1 : 835
# Missings in SPXBPEF : 835

# %% [markdown]
# # get missings for a specific column available in the df
# column_name="SMQ020"
# print(get_missings(my_df, column_name))

# %%
# identificar valores únicos
column_name="RDQ031"
unique_values = my_df[f"{column_name}"].unique()
print ("unique values for", column_name, ":", unique_values)
# Out:
# unique values for RDQ031 : [nan  2.  1.]

# %%
categorical_list=[
    "RIAGENDR",
    "raca_etnia",
    "ENQ100",
    "MCQ010",
    "RDQ031",
    "RDQ050",
    "RDQ070", 
    "RDQ090",
    "RDQ100",
    "RDQ140", 
    "AGQ030", 
    "SMQ020",
    "SMQ040"
]

# %%
print (my_df.dtypes)
for column in categorical_list:
    my_df[column]= pd.Categorical(my_df[column])
# Out:
# SEQN           float64
# RIAGENDR      category
# RIDAGEEX       float64
# raca_etnia    category
# DMDHHSIZ       float64
# BMXWT          float64
# BMXHT          float64
# BMXBMI         float64
# LBXHGB         float64
# LBXHCT         float64
# ENQ100         float64
# ENXMEAN        float64
# MCQ010        category
# MCQ025         float64
# RDQ031         float64
# RDQ050         float64
# RDQ070         float64
# RDQ090         float64
# RDQ100         float64
# RDQ134         float64
# RDQ140         float64
# AGQ030         float64
# SMQ020         float64
# SMD030         float64
# SMQ040         float64
# SPXNFVC        float64
# SPXNFEV1       float64
# SPXNPEF        float64
# SPXBFVC        float64
# SPXBFEV1       float64
# SPXBPEF        float64
# dtype: object

# %%
print (my_df.dtypes)
# Out:
# SEQN           float64
# RIAGENDR      category
# RIDAGEEX       float64
# raca_etnia    category
# DMDHHSIZ       float64
# BMXWT          float64
# BMXHT          float64
# BMXBMI         float64
# LBXHGB         float64
# LBXHCT         float64
# ENQ100        category
# ENXMEAN        float64
# MCQ010        category
# MCQ025         float64
# RDQ031        category
# RDQ050        category
# RDQ070        category
# RDQ090        category
# RDQ100        category
# RDQ134         float64
# RDQ140        category
# AGQ030        category
# SMQ020        category
# SMD030         float64
# SMQ040        category
# SPXNFVC        float64
# SPXNFEV1       float64
# SPXNPEF        float64
# SPXBFVC        float64
# SPXBFEV1       float64
# SPXBPEF        float64
# dtype: object

# %% [markdown]
# # get all values that can be present in a column
# print ("type: ", my_df[f"{column_name}"].dtype)
# values = my_df[f"{column_name}"].values
# print (values)

# %%
from docx import Document

# %%
# Criar novo documento
doc = Document()

# %%
def limpar_doc(path: str):
    """
    Limpa completamente um documento Word existente (.docx):
    - Remove todos os parágrafos
    - Remove todas as tabelas
    - Remove todas as imagens/inline shapes
    Salva de volta no mesmo ficheiro.
    
    Args:
        path (str): Caminho para o ficheiro .docx
    """
    # Abrir documento existente
    doc = Document(path)
    
    # Limpar parágrafos
    for para in doc.paragraphs:
        p = para._element
        p.getparent().remove(p)
    
    # Limpar tabelas
    for table in doc.tables:
        t = table._element
        t.getparent().remove(t)
    
    # Limpar imagens
    for shape in doc.inline_shapes:
        sp = shape._inline
        sp.getparent().remove(sp)
    
    # Salvar documento limpo
    doc.save(path)
# Adicionar título
doc.add_heading('My summary', level=1)

# %%
# Adicionar parágrafo
doc.add_paragraph('This is my report for the Winter School.')
doc.add_paragraph('Columns are' + ';'.join(columns))

# %%
# for column in columns:
#     column_missings=get_missings(my_df, column)
#     doc.add_paragraph(column + ":" +column_missings)

# %%
# Salvar
doc_name="estaeamelhorturmadawinterschool.docx"
# limpar_doc(os.path.join(d2s1_folder, "outputs",doc_name))
doc.save(os.path.join(d2s1_folder, "outputs",doc_name))

# %% [markdown]
# jupytext --to notebook meu_script.py
